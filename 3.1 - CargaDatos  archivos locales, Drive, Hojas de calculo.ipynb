# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-cb99a5d9-10f6-4ee6-97d6-4ae521cf261b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb99a5d9-10f6-4ee6-97d6-4ae521cf261b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %%
ls
# Out:
# qna-metadata.csv  qna-relacion.csv   sample_data/
# qna-pregunta.csv  qna-respuesta.csv

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/SemanaTec/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
  
# !cat /content/drive/My\ Drive/SemanaTec/foo.txt
# Out:
# Hello Google Drive!

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: 2.3 - Actualizar repositorio.ipynb, id: 189Lb2yWAkh59i9_TUNySYV7I0FeRcMu8
# title: SemanaTec, id: 1KPxuGn7g8b9VukaTxFiBT40wrdWA_ETl
# title: 2.2 Github y Collaboratory, id: 1NAgdDFlRgXEMsxVBhh4oDMGpHTXh75eRFxVoQgx4ndI
# title: 2.1 - Básicos de Unix y GIT.ipynb, id: 1-4UdnqG7HSMmXcBLcag9CC1MTO5TT6sV
# title: Reporte de Situación Problema Equipo 4, id: 11g0O1e3WB7oY4YodkgG1QGZ-_NIFR3PhMuNRe4J_W4Y
# title: Postulación a puestos de la Mesa Directiva SAITC 2021-2022, id: 1CPjMnwz-DRcbSbDsf5hHpiBfjDt8rngh0qiJc3Plo-0
# title: Genes y Genomas, id: 1HHXWBA_J1KfMWlhUmLCbUruwSFzBdFrWBHC3RmrPlak
# title: Entregable 1, id: 10a5NYWxtlwQ-oERs4bDeg_YlDLxkjkMgusTTQT_4vVA
# title: Datos personales alumnos, id: 1qNTF83I1j2P3TR9hc_ZwI27jAD6pR_7OQSIzTVJIjFg
# title:  Analogía computadora y la célula, id: 1uuVUOLaLtIjBBQCEccFpU-nA1wZXI4kRUe_3taT8xnY
# title: Macromoléculas, id: 11rLKxwn7TrKkfdxhi9RdCa-UHsgzUUllb49oAoQUbF0
# title: Respuestas a pregunta problema, id: 1u-DMwofXJwSFLxiciYs_IFaXnz3j6qHORkBfAe9bvhU
# title: PREGUNTAS SITAUCION PROBLEMA IGLESIA, id: 1oeOsKESYoZg-fly3LbzyCtqI70NdQfoxEuHOjM2fysw
# title: CV Mario Jáuregui Gómez 2021.pdf, id: 1xAasHyUo6zJm8CwYYPOObKMqCPcQJmJO
# title: Colab Notebooks, id: 1ZluFZZcmvZOFiXMmUB3ZiYR4jTCZbAX7
# title: VIDEO Y PRESENTACION FINAL, id: 11qd9JomOamajmXoRbh9ipZb3DMBi4w1P
# title: PRESENTACION BLOQUE 1, id: 1CAD5LsvsabxEZZ6D4wK_YHS1SKiWafCd6lmv4Sb8W7I
# title: Entregable de página web, id: 1E17v7DOr3ZaIcLSqVjNrVhfYCqIwCk_70DNgxEUv3Zc
# title: Fotografía.jpeg, id: 1UJIgzNYqpxWOAPjn2UUT5NxKH8ib616I
# title: Pasaporte Responsable de Pago.pdf, id: 1wUBqOrKw1wgBQ0TVADzOkgt962nlV3P1
# title: RESPONSABLE DE PAGO.pdf, id: 105NqsdaEk6qhrlpClI5xKTEADnA8eM2b
# title: Codigo de Etica.pdf, id: 1zTFf9NJBLGd1x1Ttuia8ePwfsQdwoh_n
# title: Pasaporte solicitante.pdf, id: 173TO41vSVkPjyoTzyhn7zMcv55m0d5RX
# title: CURP ALUMNO.pdf, id: 1k1O-fHM_meFFzclEEk-3CG1LILLi9vDV
# title: KARDEX OFICIAL.pdf, id: 1bQgEEWCG-GS_7CNZAz-xFicRV2TbhTiI
# title: Calificaciones Secundaria.pdf, id: 1QoidxKlZVvmJsYTjWhcbuRaNHfH998Oj
# title: ACTA DE NACIMIENTO.pdf, id: 1slkmB2h8W5WGCWHrl-PxeEdn9Q0eaF48
# title: CV Mario Jáuregui Gómez 2020.pdf, id: 1Tus4b0YxEpM-kzKZFxkZtCPdJEverD2-
# title: Formato-CV-ejemplo, id: 1EnYfLxzLgxYIbXoqgRHeMvxkCWgvx_0EgsuiIx4PweI
# title: PROYECTO INTEGRADOR , id: 1ypJZ80owLqOK0qUbaecmLr9t5c0iT_4N
# title: Video Reto Carro.mp4, id: 1AjXNGvs5apU_l7498qnaNksgKE635Wve
# title: ULTIMAS DOS PREGUNTAS, id: 1UPj0NE0XbyakNg2XZmrAxd-S6FRXlffMU8uGafOmDAA
# title: RUTA 38084, id: 18PaWNkLZa3hdBXTaWfp74i819h2eV1fE
# title: RUTA 38082, id: 1jKlB_Hoa7JHi6UaeF_mJsXzk1tLBR_an
# title: Mapa sin nombre, id: 1oZQoJusoMn7OUcwMVM1dego6O6uXKA6d
# title: RUTA 38081, id: 1shpyCXA7fP0CbnKwU2JUACeaqiVqo81M
# title: RUTA 38080, id: 1QxqjBEZbPY7PC3dtCL1BqbOUjiWabHZN
# title: Ruta 38079, id: 1nfneUCK1CqrIa_rZIkS9YTwIp376BjYy
# title: Mapa sin nombre, id: 1WOIZixrcIIngjlDHq0pU3Js-FfWiS6sC

# %%
fid= '1KPxuGn7g8b9VukaTxFiBT40wrdWA_ETl'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1kP1vx9rBL5VUGEksocMl0h_c-Qays3oe

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '1kP1vx9rBL5VUGEksocMl0h_c-Qays3oe'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('My cool spreadsheet')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1j9rvjfY2B_iNwfI2cIugf2ElbD28YBgw2SU9S7f6k1s',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': "'Hoja 1'!A1:C2",
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['2', '3', '5'], ['9', '2', '9']]
# ******************Data Frame*********************
#    0  1  2
# 0  2  3  5
# 1  9  2  9
